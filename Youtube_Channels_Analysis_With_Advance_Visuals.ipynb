# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import offline, iplot
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="plotly")

pd.options.display.float_format = "{:,.1f}".format

# %%
def update_layout(title_font_size = 28, hover_font_size = 16, hover_bgcolor = "#45FFCA", showlegend = False):
    fig.update_layout(
        showlegend = showlegend,
        title = {
            "font" : {
                "size" :title_font_size,
                "family" :"tahoma"
            }
        },
        hoverlabel={
            "bgcolor": hover_bgcolor,
            "font_size": hover_font_size,
            "font_family": "tahoma"
        }
    )

# %% [markdown]
# # Load The Dataset

# %%
# !gdown --id 1O_F-Y7jvTqhAgGeca006zM8nQQ34KUQR


df = pd.read_csv('Youtube_dataset_all_dataScience_channels.csv')
df.sample(n=10)
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1O_F-Y7jvTqhAgGeca006zM8nQQ34KUQR
# To: /content/Youtube_dataset_all_dataScience_channels.csv
# 100% 2.51M/2.51M [00:00<00:00, 133MB/s]
#            Channel_Name                                              Title  \
# 7589            Ken Jee    git for Data Science Made Simple... (Hopefully)
# 19655        ExcelIsFun  Excel & Business Math 28: IF Function, IS Func...
# 10999           CampusX  How To Build A Chatbot | Project Teaser Full V...
# 7928             Kaggle  Kaggle Live Coding: Hierarchical Document Clus...
# 4188        WsCube Tech  How to Create and Run Catalog or Shopping Ads?...
# 1443        WsCube Tech  What Are MicroServices and Monolithic Architec...
# 12656  freeCodeCamp.org  Android App Development Tutorial for Beginners...
# 7565            Ken Jee  Data Scientist Reacts: REAL Data Science Job A...
# 15256   Kevin Stratvert          How to Connect Bluetooth Headphones to PC
# 13919         Socratica                    HTTP & HTML - Socratica #Shorts
#
#       Published_date       Views  Like_count  Comment_Count
# 7589      2020-10-23    21,822.0       919.0           90.0
# 19655     2018-02-16    18,705.0       353.0           38.0
# 10999     2021-08-02       713.0        25.0            6.0
# 7928      2019-08-02     6,933.0       122.0            2.0
# 4188      2021-06-20    39,614.0     1,200.0           32.0
# 1443      2024-05-29     3,115.0       116.0           10.0
# 12656     2021-10-25   369,996.0     7,549.0          248.0
# 7565      2021-04-16    23,674.0       697.0           85.0
# 15256     2019-09-13 1,650,945.0    15,451.0          968.0
# 13919     2022-05-24    15,588.0       619.0           18.0

# %% [markdown]
# # Now, Let's Get a Quick Overview 🧐

# %%
df.shape
# Out:
# (23002, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23002 entries, 0 to 23001
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    23002 non-null  object
#  1   Title           23002 non-null  object
#  2   Published_date  23002 non-null  object
#  3   Views           23000 non-null  float64
#  4   Like_count      22967 non-null  float64
#  5   Comment_Count   22975 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # Now, It's Time For Data Cleaning & Preprocessing🧐🔨

# %%
#as the null value are in the Views Like_count Comment_Count  we can replace it will 0
df=df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23002 entries, 0 to 23001
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    23002 non-null  object
#  1   Title           23002 non-null  object
#  2   Published_date  23002 non-null  object
#  3   Views           23002 non-null  float64
#  4   Like_count      23002 non-null  float64
#  5   Comment_Count   23002 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# Channel_Name       object
# Title              object
# Published_date     object
# Views             float64
# Like_count        float64
# Comment_Count     float64
# dtype: object

# %%
df['Published_date'] = pd.to_datetime(df['Published_date'], format='%Y-%m-%d')

# %%
df['Views'] = df['Views'].astype('int64')
df['Like_count'] = df['Like_count'].astype('int64')
df['Comment_Count'] = df['Comment_Count'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23002 entries, 0 to 23001
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    23002 non-null  object
#  1   Title           23002 non-null  object
#  2   Published_date  23002 non-null  datetime64[ns]
#  3   Views           23002 non-null  int64
#  4   Like_count      23002 non-null  int64
#  5   Comment_Count   23002 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# # Now, Let's Dive Deeper Into Each Important Column 🌊🧐

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 22px arial;
#              color: lightgreen;
#              border: 2px solid lime;
#              border-radius: 8px">
# ♠ Rating Column 👦 🧔</h3>

# %%
Channel = df["Channel_Name"].value_counts()
(Channel / df.shape[0] * 100).apply(lambda x: f"{x: 0.2f} %")
# Out:
# Channel_Name
# WsCube Tech                     22.46 %
# ExcelIsFun                      16.08 %
# Krish Naik                       7.98 %
# freeCodeCamp.org                 7.28 %
# sentdex                          5.45 %
# CampusX                          4.57 %
# Guy in a Cube                    4.52 %
# codebasics                       3.83 %
# Kevin Stratvert                  3.73 %
# Socratica                        2.87 %
# Leila Gharani                    2.54 %
# Tableau Tim                      2.22 %
# Chandoo                          2.09 %
# DeepLearningAI                   1.89 %
# Kaggle                           1.65 %
# Nicholas Renotte                 1.34 %
# Alex The Analyst                 1.34 %
# Ken Jee                          1.25 %
# StatQuest with Josh Starmer      1.21 %
# Tina Huang                       0.97 %
# Luke Barousse                    0.69 %
# Ryan Nolan Data                  0.68 %
# Rob Mulla                        0.68 %
# Darshil Parmar                   0.66 %
# techTFQ                          0.59 %
# Keith Galli                      0.39 %
# Rishabh Mishra                   0.38 %
# Thu Vu data analytics            0.38 %
# Dataquest                        0.22 %
# Andrej Karpathy                  0.07 %
# Name: count, dtype: object

# %% [markdown]
# # Channel Name and Number of videos(%)

# %%
# Create the bar plot
fig = px.bar(
    data_frame=Channel.head(10),
    x=Channel.head(10).index,
    y=(Channel / sum(Channel) * 100).head(10),
    color=Channel.head(10).index,
    color_discrete_sequence=["#FF0060", "#45FFCA", "#45FFCA", "#293462", "#FF55BB", "#293462"],
    labels={"index": "Channel Name", "y": "(%)"},
    title="Channel Name and Number of videos(%)",
    text=Channel.head(10).apply(lambda x: f"{x / sum(Channel) * 100:0.2f}%"),
    template="plotly_dark"
)

# Update the layout
fig.update_layout(
    hoverlabel=dict(bgcolor="#111"),
    title_font=dict(size=24, color='lightgreen'),
    xaxis=dict(title='Channel Name'),
    yaxis=dict(title='Videos(%)'),
)

# Update traces
fig.update_traces(
    textfont={
        "family": "tahoma",
        "size": 13,
    },
    hovertemplate="Channel Name: %{x}<br>Videos: %{y:0.2f}%"
)

# Display the plot
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="985321d9-55a9-45eb-b8bc-a6fe9e57dd8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("985321d9-55a9-45eb-b8bc-a6fe9e57dd8c")) {                    Plotly.newPlot(                        "985321d9-55a9-45eb-b8bc-a6fe9e57dd8c",                        [{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"WsCube Tech","marker":{"color":"#FF0060","pattern":{"shape":""}},"name":"WsCube Tech","offsetgroup":"WsCube Tech","orientation":"v","showlegend":true,"text":["22.46%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["WsCube Tech"],"xaxis":"x","y":[22.463264063994433],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"ExcelIsFun","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"ExcelIsFun","offsetgroup":"ExcelIsFun","orientation":"v","showlegend":true,"text":["16.08%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["ExcelIsFun"],"xaxis":"x","y":[16.076862881488566],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Krish Naik","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"Krish Naik","offsetgroup":"Krish Naik","orientation":"v","showlegend":true,"text":["7.98%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Krish Naik"],"xaxis":"x","y":[7.981914616120338],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"freeCodeCamp.org","marker":{"color":"#293462","pattern":{"shape":""}},"name":"freeCodeCamp.org","offsetgroup":"freeCodeCamp.org","orientation":"v","showlegend":true,"text":["7.28%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["freeCodeCamp.org"],"xaxis":"x","y":[7.277628032345014],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"sentdex","marker":{"color":"#FF55BB","pattern":{"shape":""}},"name":"sentdex","offsetgroup":"sentdex","orientation":"v","showlegend":true,"text":["5.45%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["sentdex"],"xaxis":"x","y":[5.451699852186766],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"CampusX","marker":{"color":"#293462","pattern":{"shape":""}},"name":"CampusX","offsetgroup":"CampusX","orientation":"v","showlegend":true,"text":["4.57%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["CampusX"],"xaxis":"x","y":[4.569167898443614],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Guy in a Cube","marker":{"color":"#FF0060","pattern":{"shape":""}},"name":"Guy in a Cube","offsetgroup":"Guy in a Cube","orientation":"v","showlegend":true,"text":["4.52%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Guy in a Cube"],"xaxis":"x","y":[4.516998521867664],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"codebasics","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"codebasics","offsetgroup":"codebasics","orientation":"v","showlegend":true,"text":["3.83%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["codebasics"],"xaxis":"x","y":[3.8301017302843228],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideo ...

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 22px arial;
#              color: gold;
#              border: 3px solid tomato;
#              border-radius: 8px">
# ► From This Graph We Can Say that Ws cube tech uploads most videos !!!</h3>

# %% [markdown]
# # Number of Videos of data Science educators Through Years

# %%
view_by_year=df.groupby(df['Published_date'].dt.year)['Views'].agg('sum')
view_by_year
# Out:
# Published_date
# 2008     22028285
# 2009     27046778
# 2010     22482669
# 2011     16281280
# 2012     18730380
# 2013     26644356
# 2014     41119903
# 2015     39851964
# 2016     52591754
# 2017    111146114
# 2018    253587974
# 2019    358598249
# 2020    423369434
# 2021    502857146
# 2022    408875697
# 2023    233588129
# 2024     53260988
# Name: Views, dtype: int64

# %%
fig = px.area(view_by_year,
            x = view_by_year.index,
            y =view_by_year,
            labels = {"index" :"Year", "y" :"View Counts"},
            line_shape="spline",
            color_discrete_sequence=["#FF0060"],
            title = "Views in Data Science Content Through Years ⌛",
            template="plotly_dark",
              markers="O",

       )


update_layout()

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Year: %{x}<br>View Counts: %{y:0.2s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bf2ce02c-8922-43da-988d-3c06e11eac77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf2ce02c-8922-43da-988d-3c06e11eac77")) {                    Plotly.newPlot(                        "bf2ce02c-8922-43da-988d-3c06e11eac77",                        [{"fillpattern":{"shape":""},"hovertemplate":"Year: %{x}\u003cbr\u003eView Counts: %{y:0.2s}","legendgroup":"","line":{"color":"#FF0060","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"stackgroup":"1","textfont":{"family":"tahoma","size":13},"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[22028285,27046778,22482669,16281280,18730380,26644356,41119903,39851964,52591754,111146114,253587974,358598249,423369434,502857146,408875697,233588129,53260988],"yaxis":"y","type":"scatter"}],                        {"hoverlabel":{"bgcolor":"#45FFCA","font":{"family":"tahoma","size":16}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histo ...

# %%
year=df['Published_date'].dt.year.value_counts().sort_index()
year
# Out:
# Published_date
# 2008     366
# 2009     614
# 2010     489
# 2011     359
# 2012     442
# 2013     686
# 2014     502
# 2015     621
# 2016     649
# 2017    1129
# 2018    1146
# 2019    2042
# 2020    3177
# 2021    3738
# 2022    3429
# 2023    2416
# 2024    1197
# Name: count, dtype: int64

# %%
fig = px.area(year,
        x = year.index,
        y =year,
        labels = {"index" :"Year", "y" :"Videos Counts"},
        line_shape="spline",
        color_discrete_sequence=["#45FFCA"],
        title = "Number of Videos of data Science educators Through Years 🗓️",
        template="plotly_dark",
       )


update_layout()
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00bf0267-fae0-4c09-8191-6f63f36687cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00bf0267-fae0-4c09-8191-6f63f36687cc")) {                    Plotly.newPlot(                        "00bf0267-fae0-4c09-8191-6f63f36687cc",                        [{"fillpattern":{"shape":""},"hovertemplate":"Published_date=%{x}\u003cbr\u003eVideos Counts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#45FFCA","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[366,614,489,359,442,686,502,621,649,1129,1146,2042,3177,3738,3429,2416,1197],"yaxis":"y","type":"scatter"}],                        {"hoverlabel":{"bgcolor":"#45FFCA","font":{"family":"tahoma","size":16}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 22px arial;
#              color: red;
#              border: 3px solid tomato;
#              border-radius: 8px">
#   Videos of data Science educators were highest in the year 2020-2022 probably beacuse of covid !!!</h3>

# %% [markdown]
# # Top 10 Data Science YouTube channels

# %%
df1= df.groupby('Channel_Name', as_index=False)['Views'].agg(['count', 'mean', 'sum'])
df1.columns = ['Channel_Name','video_count', 'view_mean', 'view_count']
df1
# Out:
#                    Channel_Name  video_count  view_mean  view_count
# 0              Alex The Analyst          308  115,743.2    35648897
# 1               Andrej Karpathy           15  706,170.4    10592556
# 2                       CampusX         1051   21,290.4    22376244
# 3                       Chandoo          480  100,804.1    48385963
# 4                Darshil Parmar          152   41,889.8     6367251
# 5                     Dataquest           50   42,317.3     2115867
# 6                DeepLearningAI          435   42,763.8    18602260
# 7                    ExcelIsFun         3698   41,870.3   154836529
# 8                 Guy in a Cube         1039   34,486.2    35831122
# 9                        Kaggle          380   11,231.0     4267776
# 10                  Keith Galli           89  171,108.1    15228622
# 11                      Ken Jee          287   31,429.5     9020261
# 12              Kevin Stratvert          858  492,442.0   422515221
# 13                   Krish Naik         1836   53,980.9    99108897
# 14                Leila Gharani          584  434,661.2   253842158
# 15                Luke Barousse          159  139,870.3    22239376
# 16             Nicholas Renotte          308   57,771.2    17793529
# 17               Rishabh Mishra           88  189,260.8    16654954
# 18                    Rob Mulla          157   74,500.4    11696557
# 19              Ryan Nolan Data          157    2,124.3      333511
# 20                    Socratica          661   90,099.3    59555652
# 21  StatQuest with Josh Starmer          279  236,543.9    65995736
# 22                  Tableau Tim          510    7,896.4     4027167
# 23        Thu Vu data analytics           87   91,041.4     7920602
# 24                   Tina Huang          222  141,489.0    31410567
# 25                  WsCube Tech         5167   56,595.7   292430002
# 26                   codebasics          881   97,847.2    86203394
# 27             freeCodeCamp.org         1674  433,285.6   725320015
# 28                      sentdex         1254   91,651.9   114931493
# 29                      techTFQ          136  123,595.0    16808921

# %%
df2 = df.groupby('Channel_Name', as_index=False)['Like_count'].agg(['mean', 'count', 'sum'])
df2.columns = ['Channel_Name','Like_mean', 'video_count', 'Like_count']
df2
# Out:
#                    Channel_Name  Like_mean  video_count  Like_count
# 0              Alex The Analyst    2,968.2          308      914208
# 1               Andrej Karpathy   18,209.9           15      273148
# 2                       CampusX      618.0         1051      649533
# 3                       Chandoo    2,147.4          480     1030732
# 4                Darshil Parmar    1,293.0          152      196541
# 5                     Dataquest      986.5           50       49324
# 6                DeepLearningAI      507.2          435      220638
# 7                    ExcelIsFun      283.7         3698     1048956
# 8                 Guy in a Cube      580.4         1039      603010
# 9                        Kaggle      206.3          380       78384
# 10                  Keith Galli    3,621.7           89      322333
# 11                      Ken Jee    1,138.2          287      326665
# 12              Kevin Stratvert    9,265.0          858     7949389
# 13                   Krish Naik    1,278.0         1836     2346325
# 14                Leila Gharani    9,843.7          584     5748705
# 15                Luke Barousse    4,735.2          159      752899
# 16             Nicholas Renotte    1,762.5          308      542860
# 17               Rishabh Mishra    5,960.7           88      524538
# 18                    Rob Mulla    2,980.2          157      467895
# 19              Ryan Nolan Data       72.9          157       11442
# 20                    Socratica    1,817.9          661     1201657
# 21  StatQuest with Josh Starmer    5,136.9          279     1433189
# 22                  Tableau Tim      117.6          510       59968
# 23        Thu Vu data analytics    3,831.5           87      333342
# 24                   Tina Huang    6,346.6          222     1408944
# 25                  WsCube Tech    1,408.7         5167     7278563
# 26                   codebasics    2,139.0          881     1884503
# 27             freeCodeCamp.org    9,619.8         1674    16103492
# 28                      sentdex    1,087.1         1254     1363190
# 29                      techTFQ    3,184.0          136      433019

# %%
df3 = df.groupby('Channel_Name', as_index=False)['Comment_Count'].agg(['mean', 'count', 'sum'])
df3.columns = ['Channel_Name','Comment_mean', 'video_count', 'Comment_count']
df3
# Out:
#                    Channel_Name  Comment_mean  video_count  Comment_count
# 0              Alex The Analyst         178.3          308          54931
# 1               Andrej Karpathy         634.1           15           9512
# 2                       CampusX          38.8         1051          40764
# 3                       Chandoo          89.1          480          42789
# 4                Darshil Parmar          89.3          152          13571
# 5                     Dataquest          47.6           50           2381
# 6                DeepLearningAI          15.2          435           6621
# 7                    ExcelIsFun          40.6         3698         150068
# 8                 Guy in a Cube          41.8         1039          43467
# 9                        Kaggle           7.4          380           2805
# 10                  Keith Galli         176.6           89          15720
# 11                      Ken Jee          98.0          287          28130
# 12              Kevin Stratvert         382.0          858         327783
# 13                   Krish Naik          71.0         1836         130323
# 14                Leila Gharani         362.1          584         211480
# 15                Luke Barousse         190.8          159          30337
# 16             Nicholas Renotte         130.4          308          40149
# 17               Rishabh Mishra         353.5           88          31111
# 18                    Rob Mulla          84.0          157          13193
# 19              Ryan Nolan Data           7.6          157           1192
# 20                    Socratica          80.0          661          52862
# 21  StatQuest with Josh Starmer         337.4          279          94141
# 22                  Tableau Tim          11.3          510           5744
# 23        Thu Vu data analytics         110.9           87           9648
# 24                   Tina Huang         214.9          222          47698
# 25                  WsCube Tech          40.6         5167         209701
# 26                   codebasics          93.6          881          82454
# 27             freeCodeCamp.org         297.4         1674         497821
# 28                      sentdex         108.3         1254         135869
# 29                      techTFQ         175.2          136          23824

# %%
Channel_comparison = pd.concat([df1, df2[['Like_mean','Like_count']],df3[['Comment_mean','Comment_count']]],axis=1).query('video_count>20')
Channel_comparison
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 0              Alex The Analyst          308  115,743.2    35648897
# 2                       CampusX         1051   21,290.4    22376244
# 3                       Chandoo          480  100,804.1    48385963
# 4                Darshil Parmar          152   41,889.8     6367251
# 5                     Dataquest           50   42,317.3     2115867
# 6                DeepLearningAI          435   42,763.8    18602260
# 7                    ExcelIsFun         3698   41,870.3   154836529
# 8                 Guy in a Cube         1039   34,486.2    35831122
# 9                        Kaggle          380   11,231.0     4267776
# 10                  Keith Galli           89  171,108.1    15228622
# 11                      Ken Jee          287   31,429.5     9020261
# 12              Kevin Stratvert          858  492,442.0   422515221
# 13                   Krish Naik         1836   53,980.9    99108897
# 14                Leila Gharani          584  434,661.2   253842158
# 15                Luke Barousse          159  139,870.3    22239376
# 16             Nicholas Renotte          308   57,771.2    17793529
# 17               Rishabh Mishra           88  189,260.8    16654954
# 18                    Rob Mulla          157   74,500.4    11696557
# 19              Ryan Nolan Data          157    2,124.3      333511
# 20                    Socratica          661   90,099.3    59555652
# 21  StatQuest with Josh Starmer          279  236,543.9    65995736
# 22                  Tableau Tim          510    7,896.4     4027167
# 23        Thu Vu data analytics           87   91,041.4     7920602
# 24                   Tina Huang          222  141,489.0    31410567
# 25                  WsCube Tech         5167   56,595.7   292430002
# 26                   codebasics          881   97,847.2    86203394
# 27             freeCodeCamp.org         1674  433,285.6   725320015
# 28                      sentdex         1254   91,651.9   114931493
# 29                      techTFQ          136  123,595.0    16808921
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 0     2,968.2      914208         178.3          54931
# 2       618.0      649533          38.8          40764
# 3     2,147.4     1030732          89.1          42789
# 4     1,293.0      196541          89.3          13571
# 5       986.5       49324          47.6           2381
# 6       507.2      220638          15.2           6621
# 7       283.7     1048956          40.6         150068
# 8       580.4      603010          41.8          43467
# 9       206.3       78384           7.4           2805
# 10    3,621.7      322333         176.6          15720
# 11    1,138.2      326665          98.0          28130
# 12    9,265.0     7949389         382.0         327783
# 13    1,278.0     2346325          71.0         130323
# 14    9,843.7     5748705         362.1         211480
# 15    4,735.2      752899         190.8          30337
# 16    1,762.5      542860         130.4          40149
# 17    5,960.7      524538         353.5          31111
# 18    2,980.2      467895          84.0          13193
# 19       72.9       11442           7.6           1192
# 20    1,817.9     1201657          80.0          52862
# 21    5,136.9     1433189         337.4          94141
# 22      117.6       59968          11.3           5744
# 23    3,831.5      333342         110.9           9648
# 24    6,346.6     1408944         214.9          47698
# 25    1,408.7     7278563          40.6         209701
# 26    2,139.0     1884503          93.6          82454
# 27    9,619.8    16103492         297.4         497821
# 28    1,087.1     1363190         108.3         135869
# 29    3,184.0      433019         175.2          23824

# %%
channel_views=Channel_comparison.sort_values(by='view_mean',ascending=True)
channel_views.tail(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 0              Alex The Analyst          308  115,743.2    35648897
# 29                      techTFQ          136  123,595.0    16808921
# 15                Luke Barousse          159  139,870.3    22239376
# 24                   Tina Huang          222  141,489.0    31410567
# 10                  Keith Galli           89  171,108.1    15228622
# 17               Rishabh Mishra           88  189,260.8    16654954
# 21  StatQuest with Josh Starmer          279  236,543.9    65995736
# 27             freeCodeCamp.org         1674  433,285.6   725320015
# 14                Leila Gharani          584  434,661.2   253842158
# 12              Kevin Stratvert          858  492,442.0   422515221
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 0     2,968.2      914208         178.3          54931
# 29    3,184.0      433019         175.2          23824
# 15    4,735.2      752899         190.8          30337
# 24    6,346.6     1408944         214.9          47698
# 10    3,621.7      322333         176.6          15720
# 17    5,960.7      524538         353.5          31111
# 21    5,136.9     1433189         337.4          94141
# 27    9,619.8    16103492         297.4         497821
# 14    9,843.7     5748705         362.1         211480
# 12    9,265.0     7949389         382.0         327783

# %%
fig = px.bar(
    data_frame= channel_views.tail(10),
    orientation = "h",
    y = channel_views.tail(10).Channel_Name,
    x = channel_views.tail(10).view_mean,
    color = channel_views.tail(10).view_mean,

    labels = {"x": "average views", "y" : "Data Science YouTube channels"},
    title = "Top 10 Data Science YouTube channels with highest average views",
    text_auto= ".2s",
    template = "plotly_dark",
     color_continuous_scale=['#A084E8', '#00FFAB', '#00FFAB']
      )

update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textposition = "outside",
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Data Science YouTube channels: %{y}<br>average views: %{x:0.3s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73838889-231f-43d1-91cd-65a94bfc2b33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73838889-231f-43d1-91cd-65a94bfc2b33")) {                    Plotly.newPlot(                        "73838889-231f-43d1-91cd-65a94bfc2b33",                        [{"alignmentgroup":"True","hovertemplate":"Data Science YouTube channels: %{y}\u003cbr\u003eaverage views: %{x:0.3s}","legendgroup":"","marker":{"color":[115743.17207792208,123595.00735294117,139870.2893081761,141489.04054054053,171108.11235955055,189260.8409090909,236543.85663082436,433285.5525686977,434661.2294520548,492441.98251748254],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"textposition":"outside","texttemplate":"%{x:.2s}","x":[115743.17207792208,123595.00735294117,139870.2893081761,141489.04054054053,171108.11235955055,189260.8409090909,236543.85663082436,433285.5525686977,434661.2294520548,492441.98251748254],"xaxis":"x","y":["Alex The Analyst","techTFQ","Luke Barousse","Tina Huang","Keith Galli","Rishabh Mishra","StatQuest with Josh Starmer","freeCodeCamp.org","Leila Gharani","Kevin Stratvert"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#A084E8"],[0.5,"#00FFAB"],[1.0,"#00FFAB"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...

# %%
channel_Like_mean=Channel_comparison.sort_values(by='Like_mean',ascending=False)
channel_Like_mean.head(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 14                Leila Gharani          584  434,661.2   253842158
# 27             freeCodeCamp.org         1674  433,285.6   725320015
# 12              Kevin Stratvert          858  492,442.0   422515221
# 24                   Tina Huang          222  141,489.0    31410567
# 17               Rishabh Mishra           88  189,260.8    16654954
# 21  StatQuest with Josh Starmer          279  236,543.9    65995736
# 15                Luke Barousse          159  139,870.3    22239376
# 23        Thu Vu data analytics           87   91,041.4     7920602
# 10                  Keith Galli           89  171,108.1    15228622
# 29                      techTFQ          136  123,595.0    16808921
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 14    9,843.7     5748705         362.1         211480
# 27    9,619.8    16103492         297.4         497821
# 12    9,265.0     7949389         382.0         327783
# 24    6,346.6     1408944         214.9          47698
# 17    5,960.7      524538         353.5          31111
# 21    5,136.9     1433189         337.4          94141
# 15    4,735.2      752899         190.8          30337
# 23    3,831.5      333342         110.9           9648
# 10    3,621.7      322333         176.6          15720
# 29    3,184.0      433019         175.2          23824

# %%
fig = px.bar(channel_Like_mean.head(10),
                 x = "Channel_Name",
                 y = "Like_mean",
                 color = "Channel_Name",
                 template = "plotly_dark",
                 color_discrete_sequence=["#45FFCA","#FF0060","#FF55BB", "#FFFDAF"],
                 opacity = 0.89,
                title = "Top 10 Data Science YouTube channels with highest average Likes")


update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Channel_Name: %{x}<br>average Likes: %{y}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c5a6bf42-7d7e-432b-995d-40fd1b40d87a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5a6bf42-7d7e-432b-995d-40fd1b40d87a")) {                    Plotly.newPlot(                        "c5a6bf42-7d7e-432b-995d-40fd1b40d87a",                        [{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Leila Gharani","marker":{"color":"#45FFCA","opacity":0.89,"pattern":{"shape":""}},"name":"Leila Gharani","offsetgroup":"Leila Gharani","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Leila Gharani"],"xaxis":"x","y":[9843.672945205479],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"freeCodeCamp.org","marker":{"color":"#FF0060","opacity":0.89,"pattern":{"shape":""}},"name":"freeCodeCamp.org","offsetgroup":"freeCodeCamp.org","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["freeCodeCamp.org"],"xaxis":"x","y":[9619.768219832737],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Kevin Stratvert","marker":{"color":"#FF55BB","opacity":0.89,"pattern":{"shape":""}},"name":"Kevin Stratvert","offsetgroup":"Kevin Stratvert","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Kevin Stratvert"],"xaxis":"x","y":[9265.022144522145],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Tina Huang","marker":{"color":"#FFFDAF","opacity":0.89,"pattern":{"shape":""}},"name":"Tina Huang","offsetgroup":"Tina Huang","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Tina Huang"],"xaxis":"x","y":[6346.594594594595],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Rishabh Mishra","marker":{"color":"#45FFCA","opacity":0.89,"pattern":{"shape":""}},"name":"Rishabh Mishra","offsetgroup":"Rishabh Mishra","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Rishabh Mishra"],"xaxis":"x","y":[5960.659090909091],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"StatQuest with Josh Starmer","marker":{"color":"#FF0060","opacity":0.89,"pattern":{"shape":""}},"name":"StatQuest with Josh Starmer","offsetgroup":"StatQuest with Josh Starmer","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["StatQuest with Josh Starmer"],"xaxis":"x","y":[5136.878136200717],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Luke Barousse","marker":{"color":"#FF55BB","opacity":0.89,"pattern":{"shape":""}},"name":"Luke Barousse","offsetgroup":"Luke Barousse","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Luke Barousse"],"xaxis":"x","y":[4735.213836477988],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Thu Vu data analytics","marker":{"color":"#FFFDAF","opacity":0.89,"pattern":{"shape":""}},"name":"Thu Vu data analytics","offsetgroup":"Thu Vu data analytics","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x": ...

# %%
channel_Comment_mean=Channel_comparison.sort_values(by='Comment_mean',ascending=True)
channel_Comment_mean.tail(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 29                      techTFQ          136  123,595.0    16808921
# 10                  Keith Galli           89  171,108.1    15228622
# 0              Alex The Analyst          308  115,743.2    35648897
# 15                Luke Barousse          159  139,870.3    22239376
# 24                   Tina Huang          222  141,489.0    31410567
# 27             freeCodeCamp.org         1674  433,285.6   725320015
# 21  StatQuest with Josh Starmer          279  236,543.9    65995736
# 17               Rishabh Mishra           88  189,260.8    16654954
# 14                Leila Gharani          584  434,661.2   253842158
# 12              Kevin Stratvert          858  492,442.0   422515221
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 29    3,184.0      433019         175.2          23824
# 10    3,621.7      322333         176.6          15720
# 0     2,968.2      914208         178.3          54931
# 15    4,735.2      752899         190.8          30337
# 24    6,346.6     1408944         214.9          47698
# 27    9,619.8    16103492         297.4         497821
# 21    5,136.9     1433189         337.4          94141
# 17    5,960.7      524538         353.5          31111
# 14    9,843.7     5748705         362.1         211480
# 12    9,265.0     7949389         382.0         327783

# %%
fig = px.scatter(channel_Comment_mean.tail(10),
                 y = "Channel_Name",
                 x = "Comment_mean",
                 size = "Comment_mean",
                 color = "Comment_mean",
                 template = "plotly_dark",
                 labels={"name" :"Data Science YouTube channels", "score" :"average comments"},
                 opacity = 0.89,
                title = "Top 10 Data Science YouTube channels with highest average comments",
                color_continuous_scale=['#A084E8', '#8BE8E5', '#00FFAB'])


update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "YouTube channels: %{y}<br>average comments: %{x}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="be71ecff-b43f-4396-a2fd-541e79456fa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be71ecff-b43f-4396-a2fd-541e79456fa4")) {                    Plotly.newPlot(                        "be71ecff-b43f-4396-a2fd-541e79456fa4",                        [{"hovertemplate":"YouTube channels: %{y}\u003cbr\u003eaverage comments: %{x}","legendgroup":"","marker":{"color":[175.1764705882353,176.62921348314606,178.3474025974026,190.7987421383648,214.85585585585585,297.384109916368,337.42293906810033,353.53409090909093,362.1232876712329,382.03146853146853],"coloraxis":"coloraxis","opacity":0.89,"size":[175.1764705882353,176.62921348314606,178.3474025974026,190.7987421383648,214.85585585585585,297.384109916368,337.42293906810033,353.53409090909093,362.1232876712329,382.03146853146853],"sizemode":"area","sizeref":0.9550786713286713,"symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"x":[175.1764705882353,176.62921348314606,178.3474025974026,190.7987421383648,214.85585585585585,297.384109916368,337.42293906810033,353.53409090909093,362.1232876712329,382.03146853146853],"xaxis":"x","y":["techTFQ","Keith Galli","Alex The Analyst","Luke Barousse","Tina Huang","freeCodeCamp.org","StatQuest with Josh Starmer","Rishabh Mishra","Leila Gharani","Kevin Stratvert"],"yaxis":"y","type":"scatter"}],                        {"coloraxis":{"colorbar":{"title":{"text":"Comment_mean"}},"colorscale":[[0.0,"#A084E8"],[0.5,"#8BE8E5"],[1.0,"#00FFAB"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"itemsizing":"constant","tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111111 ...

# %% [markdown]
# <h3 style = "background-color: #010101;
#              padding: 15px;
#              font: bold 20px arial;
#              color: gold;
#              border: 2px solid tomato;
#              border-radius: 8px">
# ♣ Now, will these 3 visuals we can notice some common youtube channels name we can say that probably they are the  <span style = "color: tomato">Best Data Science Educators</span> in The YouTube !! 👑🎬</h3>

# %% [markdown]
# #  Correlation

# %% [markdown]
# <h3 style = "background-color: #010101;
#              padding: 18px;
#              font: bold 24px arial;
#              color: #45FFCA;
#              border: 2px solid green;
#              border-radius: 8px">
# ♣ Is There Any Correlation in the data set?!🎬</h3>

# %%
df_corr = Channel_comparison[["video_count", "view_mean",  "Like_mean", "Comment_mean"]]

# %%
df_corr.corr(numeric_only=True)
# Out:
#               video_count  view_mean  Like_mean  Comment_mean
# video_count           1.0       -0.0       -0.1          -0.2
# view_mean            -0.0        1.0        0.9           0.9
# Like_mean            -0.1        0.9        1.0           0.9
# Comment_mean         -0.2        0.9        0.9           1.0

# %%
# Create The Plotly Heat Map
fig = px.imshow(
    df_corr.corr(numeric_only = True),
    text_auto="0.2f", aspect="auto", template="plotly_dark",
    title="Correlation",
    color_continuous_scale = "earth"
)

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Feature[1]: %{x}<br>Feature[2]: %{y}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd77343d-3aa1-4c8b-bebc-072066aacab4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd77343d-3aa1-4c8b-bebc-072066aacab4")) {                    Plotly.newPlot(                        "bd77343d-3aa1-4c8b-bebc-072066aacab4",                        [{"coloraxis":"coloraxis","hovertemplate":"Feature[1]: %{x}\u003cbr\u003eFeature[2]: %{y}","name":"0","textfont":{"family":"tahoma","size":16},"texttemplate":"%{z:0.2f}","x":["video_count","view_mean","Like_mean","Comment_mean"],"xaxis":"x","y":["video_count","view_mean","Like_mean","Comment_mean"],"yaxis":"y","z":[[1.0,-0.03656619027450424,-0.13219059510453643,-0.200115342375564],[-0.03656619027450424,1.0,0.9472024061017618,0.8893615448033293],[-0.13219059510453643,0.9472024061017618,1.0,0.9223628218834196],[-0.200115342375564,0.8893615448033293,0.9223628218834196,1.0]],"type":"heatmap"}],                        {"coloraxis":{"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":15}},"showlegend":true,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...

# %% [markdown]
# <h3 style = "background-color: #000;
#              padding: 18px;
#              font: bold 20px tahoma;
#              color: gold;
#              border: 3px solid tomato;
#              border-radius: 8px">
#     ► From The HeatMap, We Can Say 😉🧐
#     <BR><HR style = "border: 1px solid #555">
#         1) There Is a Very Strong Positive Correlation Between <U>view_mean</U> and <U>Like_mean</U> (1.0)🔗..
#     <BR>
#         2) There Is a Strong Positive Correlation Between <U>view_mean</U> and <U>Comment_mean</U> (0.89)🔗
#
#
# </h3>

# %%
fig = px.scatter(
    Channel_comparison,
    x = Channel_comparison["view_mean"],
    y = Channel_comparison["Like_mean"],
    trendline="ols",
    template="plotly_dark",
    color = Channel_comparison["Like_mean"],
    color_discrete_sequence=["#45FFCA"],
    title = "Relation Between Views & Likes",

          )

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)
fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Views: %{x:0.3s}<br>Likes: %{y:0.3s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eeabd019-6ddf-4d07-848e-dd35f1cd7e3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeabd019-6ddf-4d07-848e-dd35f1cd7e3d")) {                    Plotly.newPlot(                        "eeabd019-6ddf-4d07-848e-dd35f1cd7e3d",                        [{"hovertemplate":"Views: %{x:0.3s}\u003cbr\u003eLikes: %{y:0.3s}","legendgroup":"","marker":{"color":[2968.2077922077924,618.0142721217887,2147.358333333333,1293.032894736842,986.48,507.21379310344827,283.65494862087616,580.3753609239653,206.2736842105263,3621.7191011235955,1138.205574912892,9265.022144522145,1277.9547930283225,9843.672945205479,4735.213836477988,1762.5324675324675,5960.659090909091,2980.2229299363057,72.87898089171975,1817.9379727685325,5136.878136200717,117.58431372549019,3831.5172413793102,6346.594594594595,1408.6632475324172,2139.049943246311,9619.768219832737,1087.07336523126,3183.9632352941176],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[115743.17207792208,21290.431969552807,100804.08958333333,41889.80921052631,42317.34,42763.816091954024,41870.343158464035,34486.161693936476,11230.98947368421,171108.11235955055,31429.480836236933,492441.98251748254,53980.88071895425,434661.2294520548,139870.2893081761,57771.19805194805,189260.8409090909,74500.36305732484,2124.2738853503183,90099.32223903177,236543.85663082436,7896.405882352941,91041.40229885057,141489.04054054053,56595.70389007161,97847.21225879682,433285.5525686977,91651.90829346092,123595.00735294117],"xaxis":"x","y":[2968.2077922077924,618.0142721217887,2147.358333333333,1293.032894736842,986.48,507.21379310344827,283.65494862087616,580.3753609239653,206.2736842105263,3621.7191011235955,1138.205574912892,9265.022144522145,1277.9547930283225,9843.672945205479,4735.213836477988,1762.5324675324675,5960.659090909091,2980.2229299363057,72.87898089171975,1817.9379727685325,5136.878136200717,117.58431372549019,3831.5172413793102,6346.594594594595,1408.6632475324172,2139.049943246311,9619.768219832737,1087.07336523126,3183.9632352941176],"yaxis":"y","type":"scatter"},{"hovertemplate":"Views: %{x:0.3s}\u003cbr\u003eLikes: %{y:0.3s}","legendgroup":"","marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[2124.2738853503183,7896.405882352941,11230.98947368421,21290.431969552807,31429.480836236933,34486.161693936476,41870.343158464035,41889.80921052631,42317.34,42763.816091954024,53980.88071895425,56595.70389007161,57771.19805194805,74500.36305732484,90099.32223903177,91041.40229885057,91651.90829346092,97847.21225879682,100804.08958333333,115743.17207792208,123595.00735294117,139870.2893081761,141489.04054054053,171108.11235955055,189260.8409090909,236543.85663082436,433285.5525686977,434661.2294520548,492441.98251748254],"xaxis":"x","y":[435.7064891500119,558.1653286969602,628.910286916691,842.3266909720753,1057.431986375696,1122.2810908129527,1278.940414199822,1279.353396811333,1288.4236891013784,1297.8959160245568,1535.8718871317442,1591.346746563542,1616.2854782197744,1971.2035802679743,2302.1437667578184,2322.1304945294005,2335.0827027732976,2466.519359909622,2529.251079494943,2846.191632332864,3012.7724791658775,3358.0612117472565,3392.4038770801826,4020.788183831516,4405.907940957968,5409.04217949762,9583.02153193819,9612.207246127497,10838.056546215468],"yaxis":"y","type":"scatter"}],                        {"coloraxis":{"colorbar":{"title":{"text":"Like_mean"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %%
fig = px.scatter(
    Channel_comparison,
    x = Channel_comparison["view_mean"],
    y = Channel_comparison["Comment_mean"],
    trendline="ols",
    template="plotly_dark",
    color = Channel_comparison["Comment_mean"],
    color_discrete_sequence=["#45FFCA"],
    title = "Relation Between Views & Comments",

          )

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)
fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Views: %{x:0.4s}<br>Comments: %{y:0.4s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f1ecb574-e3c3-4836-afd4-7c0042294107" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1ecb574-e3c3-4836-afd4-7c0042294107")) {                    Plotly.newPlot(                        "f1ecb574-e3c3-4836-afd4-7c0042294107",                        [{"hovertemplate":"Views: %{x:0.4s}\u003cbr\u003eComments: %{y:0.4s}","legendgroup":"","marker":{"color":[178.3474025974026,38.78591817316841,89.14375,89.28289473684211,47.62,15.220689655172414,40.58085451595457,41.83541867179981,7.381578947368421,176.62921348314606,98.01393728222996,382.03146853146853,70.98202614379085,362.1232876712329,190.7987421383648,130.3538961038961,353.53409090909093,84.03184713375796,7.592356687898089,79.97276853252647,337.42293906810033,11.262745098039217,110.89655172413794,214.85585585585585,40.58467195664796,93.59137343927355,297.384109916368,108.34848484848484,175.1764705882353],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[115743.17207792208,21290.431969552807,100804.08958333333,41889.80921052631,42317.34,42763.816091954024,41870.343158464035,34486.161693936476,11230.98947368421,171108.11235955055,31429.480836236933,492441.98251748254,53980.88071895425,434661.2294520548,139870.2893081761,57771.19805194805,189260.8409090909,74500.36305732484,2124.2738853503183,90099.32223903177,236543.85663082436,7896.405882352941,91041.40229885057,141489.04054054053,56595.70389007161,97847.21225879682,433285.5525686977,91651.90829346092,123595.00735294117],"xaxis":"x","y":[178.3474025974026,38.78591817316841,89.14375,89.28289473684211,47.62,15.220689655172414,40.58085451595457,41.83541867179981,7.381578947368421,176.62921348314606,98.01393728222996,382.03146853146853,70.98202614379085,362.1232876712329,190.7987421383648,130.3538961038961,353.53409090909093,84.03184713375796,7.592356687898089,79.97276853252647,337.42293906810033,11.262745098039217,110.89655172413794,214.85585585585585,40.58467195664796,93.59137343927355,297.384109916368,108.34848484848484,175.1764705882353],"yaxis":"y","type":"scatter"},{"hovertemplate":"Views: %{x:0.4s}\u003cbr\u003eComments: %{y:0.4s}","legendgroup":"","marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[2124.2738853503183,7896.405882352941,11230.98947368421,21290.431969552807,31429.480836236933,34486.161693936476,41870.343158464035,41889.80921052631,42317.34,42763.816091954024,53980.88071895425,56595.70389007161,57771.19805194805,74500.36305732484,90099.32223903177,91041.40229885057,91651.90829346092,97847.21225879682,100804.08958333333,115743.17207792208,123595.00735294117,139870.2893081761,141489.04054054053,171108.11235955055,189260.8409090909,236543.85663082436,433285.5525686977,434661.2294520548,492441.98251748254],"xaxis":"x","y":[40.608160018028094,45.174647366517995,47.81272525354546,55.77101811900654,63.79228970452759,66.21051133776545,72.05233395274185,72.06773406495577,72.40596505867444,72.75918418574395,81.63330274938546,83.70195899904265,84.63192373672015,97.86681171009344,110.20756375628106,110.95286838144575,111.43585593301475,116.33712589573332,118.67639029587947,130.49509632079565,136.70689231998983,149.58270132440623,150.86333853554123,174.29577507818422,188.65688208424248,226.06373508134433,381.71133043905286,382.7996650590377,428.5115576485542],"yaxis":"y","type":"scatter"}],                        {"coloraxis":{"colorbar":{"title":{"text":"Comment_mean"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b" ...

# %% [markdown]
# # Now lets try to find best videos📺

# %%
df.sample(10)
# Out:
#            Channel_Name                                              Title  \
# 12838  freeCodeCamp.org  Full React Course 2020 - Learn Fundamentals, H...
# 2251        WsCube Tech  What is Gradient & How to Add It to App Backgr...
# 20150        ExcelIsFun  Excel 2013 Statistical Analysis #67: Hypothesi...
# 6651         codebasics                       Resume Project Challenge 10!
# 13529  freeCodeCamp.org  Styling React with MaterialUI Part 2 (P4D6) - ...
# 21733        ExcelIsFun  Excel Dynamic Chart #13: Web Query Stock Perce...
# 2935        WsCube Tech  JavaScript Date Methods Tutorial in Hindi (The...
# 3033        WsCube Tech  What is Google Analytics & How Does It Work? B...
# 5138        WsCube Tech  How to do Content Stacking Practically - Insta...
# 5289        WsCube Tech  Using Bootstrap Grid Layout  | Learn Bootstrap...
#
#       Published_date    Views  Like_count  Comment_Count
# 12838     2020-10-06  2625210       50452           2123
# 2251      2022-11-09    17054         324             21
# 20150     2015-05-30     5717          30              3
# 6651      2024-03-04     2949         124              5
# 13529     2017-10-10     2616          39              3
# 21733     2009-12-16    12732          32              6
# 2935      2022-05-19     2735          45              2
# 3033      2022-04-29   169544        4986            108
# 5138      2020-11-21     6380         173              3
# 5289      2020-10-17     2677          45              4

# %%
best_videos=df.sort_values(by=['Views', 'Like_count', 'Comment_Count'], ascending=True)
best_videos.tail(10)
# Out:
#            Channel_Name                                              Title  \
# 12929  freeCodeCamp.org  Introduction to Programming and Computer Scien...
# 12824  freeCodeCamp.org  Microsoft Excel Tutorial for Beginners - Full ...
# 6638         codebasics     Don't put toy dataset projects on your resume!
# 12506  freeCodeCamp.org  Harvard CS50 – Full Computer Science Universit...
# 13254  freeCodeCamp.org               C Programming Tutorial for Beginners
# 13242  freeCodeCamp.org           C++ Tutorial for Beginners - Full Course
# 13102  freeCodeCamp.org       Learn JavaScript - Full Course for Beginners
# 13312  freeCodeCamp.org  SQL Tutorial - Full Database Course for Beginners
# 3825        WsCube Tech  Ethical HACKING Full Course in 10 HOURS (Begin...
# 13295  freeCodeCamp.org  Learn Python - Full Course for Beginners [Tuto...
#
#       Published_date     Views  Like_count  Comment_Count
# 12929     2020-04-21   8284519      198815           4112
# 12824     2020-10-28   9035366      150453           2462
# 6638      2024-03-22   9352112      173395            545
# 12506     2022-10-19  11116950      438036           7335
# 13254     2018-08-15  11452401      195881           6686
# 13242     2018-08-24  12280808      281268          11974
# 13102     2018-12-10  17141758      258906           8558
# 13312     2018-07-02  18100085      340592          11119
# 3825      2021-08-29  22017238      581831           7774
# 13295     2018-07-11  44267093     1041273          44343

# %%
fig = px.bar(
    data_frame=best_videos.tail(10),
    orientation="h",
    y=best_videos.tail(10).Title,
    x=best_videos.tail(10).Views,
    color=best_videos.tail(10).Views,
    labels={"x": "View,Likes and Comment", "y": "Videos"},
    title="Top 10 Videos on the basis of View,Likes and Comment",
    text_auto=".2s",
    template="plotly_dark",
    color_continuous_scale=['#FF5733', '#C70039', '#900C3F']
)
update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textposition = "outside",
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Videos: %{y}<br>AVG View: %{x:0.3s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6b351831-fa6d-4545-b554-57d49299d514" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b351831-fa6d-4545-b554-57d49299d514")) {                    Plotly.newPlot(                        "6b351831-fa6d-4545-b554-57d49299d514",                        [{"alignmentgroup":"True","hovertemplate":"Videos: %{y}\u003cbr\u003eAVG View: %{x:0.3s}","legendgroup":"","marker":{"color":[8284519,9035366,9352112,11116950,11452401,12280808,17141758,18100085,22017238,44267093],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"textposition":"outside","texttemplate":"%{x:.2s}","x":[8284519,9035366,9352112,11116950,11452401,12280808,17141758,18100085,22017238,44267093],"xaxis":"x","y":["Introduction to Programming and Computer Science - Full Course","Microsoft Excel Tutorial for Beginners - Full Course","Don't put toy dataset projects on your resume!","Harvard CS50 – Full Computer Science University Course","C Programming Tutorial for Beginners","C++ Tutorial for Beginners - Full Course","Learn JavaScript - Full Course for Beginners","SQL Tutorial - Full Database Course for Beginners","Ethical HACKING Full Course in 10 HOURS (Beginners to Pro) | Learn Ethical Hacking 2024","Learn Python - Full Course for Beginners [Tutorial]"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#FF5733"],[0.5,"#C70039"],[1.0,"#900C3F"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %% [markdown]
# <h3 style = "background-color: #111;
#              padding: 15px;
#              font: bold 18px arial;
#              color: lightgreen;
#              border: 2px solid lime;
#              border-radius: 8px">
# ► These are the best video according to the audience .
# <BR>
